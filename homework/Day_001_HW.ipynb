# %% [markdown]
# # 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    """
    請完成這個 Function 後往下執行
    """
    mse = sum((y - y_hat)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 247.517
# The Mean absolute error is 12.808

# %% [markdown]
# ## 作業1
# ### Competitions: Google Landmark Recognition 2019
# 1. 選的這組資料為何重要 ans: 地標可用於導覽，例如旅遊時執到什麼地方，就能告訴你身邊有什麼重要的地標，對於盲人也是個福音。
# 2. 資料從何而來 ans: 從網路收集許可的地標圖像，由群眾標示的資料。
# 3. 蒐集而來的資料的型態為何 ans: CSV和影像，CSV列出訓練資料影像的id、url和label的id
# 4. 這組資料想解決的問題如何評估 ans: 該競賽明確列出評估方式為Global Average Precision (GAP)，公式請見該 [競賽網頁](https://www.kaggle.com/c/landmark-recognition-2019/overview/evaluation)

# %% [markdown]
# ## 作業2
# 1. 核心問題為何 ans: 自由載客車隊需要透過宣傳和企業形象提升業績，要宣傳就要針對重點區域，才能有效率。
# 2. 資料從何而來 ans: 重點區域旅遊區、飯店旅館、車站，資料需要每日造訪人次、旅客的年齡層、性別、時間等資料，收集方式可能為實地訪查和監視影像。
# 3. 蒐集而來的資料型態為何 ans: 造訪人次、年齡層、時間為數值資料，性別為類別資料，若為影像，同樣要透過辨識，計數人次、估計年齡和性別等，轉為資料。
# 4. 你要回答的問題 ans: 那個區域的那個時間點旅客最多，搭車意願最高，有投放廣告的成效如何，成交的載客人數是否會增加。
